# %%
import network
import load_data
import make_plot
import numpy as np
import matplotlib.pyplot as plt
import imp

# %%
#加载数据
X,y=load_data.load_data()

# %%
X
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]])

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
imp.reload(make_plot)#修改以后需要重新装入模块
imp.reload(network)
# Out:
# <module 'network' from 'D:\\Jupyter\\神经网络\\蘑菇\\network.py'>

# %%
train_data,test_data=load_data.adjust_data(X,y)   #分类：训练集、测试集

# %%
#make_plot.make_plot(epochs,list1,list2,label1,label2,xlabel,ylabel,title,png_name)
make_plot.compare_cost(train_data,test_data)

# %%
make_plot.compare_QC_layers(train_data,test_data)
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 2282 / 2438
# Epoch 1 training complete
# Accuracy on evaluation data: 2354 / 2438
# Epoch 2 training complete
# Accuracy on evaluation data: 2362 / 2438
# Epoch 3 training complete
# Accuracy on evaluation data: 2413 / 2438
# Epoch 4 training complete
# Accuracy on evaluation data: 2411 / 2438
# Epoch 5 training complete
# Accuracy on evaluation data: 2424 / 2438
# Epoch 6 training complete
# Accuracy on evaluation data: 2423 / 2438
# Epoch 7 training complete
# Accuracy on evaluation data: 2427 / 2438
# Epoch 8 training complete
# Accuracy on evaluation data: 2434 / 2438
# Epoch 9 training complete
# Accuracy on evaluation data: 2433 / 2438
# Epoch 10 training complete
# Accuracy on evaluation data: 2433 / 2438
# Epoch 11 training complete
# Accuracy on evaluation data: 2433 / 2438
# Epoch 12 training complete
# Accuracy on evaluation data: 2437 / 2438
# Epoch 13 training complete
# Accuracy on evaluation data: 2434 / 2438
# ...

# %%
make_plot.compare_CEC_layers(train_data,test_data)
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 2313 / 2438
# Epoch 1 training complete
# Accuracy on evaluation data: 2347 / 2438
# Epoch 2 training complete
# Accuracy on evaluation data: 2168 / 2438
# Epoch 3 training complete
# Accuracy on evaluation data: 2344 / 2438
# Epoch 4 training complete
# Accuracy on evaluation data: 2321 / 2438
# Epoch 5 training complete
# Accuracy on evaluation data: 2365 / 2438
# Epoch 6 training complete
# Accuracy on evaluation data: 2381 / 2438
# Epoch 7 training complete
# Accuracy on evaluation data: 2348 / 2438
# Epoch 8 training complete
# Accuracy on evaluation data: 2350 / 2438
# Epoch 9 training complete
# Accuracy on evaluation data: 2304 / 2438
# Epoch 10 training complete
# Accuracy on evaluation data: 2360 / 2438
# Epoch 11 training complete
# Accuracy on evaluation data: 2344 / 2438
# Epoch 12 training complete
# Accuracy on evaluation data: 2378 / 2438
# Epoch 13 training complete
# Accuracy on evaluation data: 2318 / 2438
# ...

# %%
make_plot.compare_mini_batch_size(train_data,test_data)
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 2283 / 2438
# Epoch 1 training complete
# Accuracy on evaluation data: 2287 / 2438
# Epoch 2 training complete
# Accuracy on evaluation data: 2357 / 2438
# Epoch 3 training complete
# Accuracy on evaluation data: 2384 / 2438
# Epoch 4 training complete
# Accuracy on evaluation data: 2403 / 2438
# Epoch 5 training complete
# Accuracy on evaluation data: 2406 / 2438
# Epoch 6 training complete
# Accuracy on evaluation data: 2420 / 2438
# Epoch 7 training complete
# Accuracy on evaluation data: 2427 / 2438
# Epoch 8 training complete
# Accuracy on evaluation data: 2426 / 2438
# Epoch 9 training complete
# Accuracy on evaluation data: 2430 / 2438
# Epoch 10 training complete
# Accuracy on evaluation data: 2433 / 2438
# Epoch 11 training complete
# Accuracy on evaluation data: 2420 / 2438
# Epoch 12 training complete
# Accuracy on evaluation data: 2436 / 2438
# Epoch 13 training complete
# Accuracy on evaluation data: 2430 / 2438
# ...

# %%
make_plot.compare_eta(train_data,test_data)

# %%
make_plot.compare_lmbda(train_data,test_data)

# %%
make_plot.best_network(train_data,test_data)
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 2214 / 2438
# Epoch 1 training complete
# Accuracy on evaluation data: 2340 / 2438
# Epoch 2 training complete
# Accuracy on evaluation data: 2380 / 2438
# Epoch 3 training complete
# Accuracy on evaluation data: 2395 / 2438
# Epoch 4 training complete
# Accuracy on evaluation data: 2395 / 2438
# Epoch 5 training complete
# Accuracy on evaluation data: 2414 / 2438
# Epoch 6 training complete
# Accuracy on evaluation data: 2417 / 2438
# Epoch 7 training complete
# Accuracy on evaluation data: 2419 / 2438
# Epoch 8 training complete
# Accuracy on evaluation data: 2408 / 2438
# Epoch 9 training complete
# Accuracy on evaluation data: 2423 / 2438
# Epoch 10 training complete
# Accuracy on evaluation data: 2418 / 2438
# Epoch 11 training complete
# Accuracy on evaluation data: 2431 / 2438
# Epoch 12 training complete
# Accuracy on evaluation data: 2429 / 2438
# Epoch 13 training complete
# Accuracy on evaluation data: 2436 / 2438
# ...
